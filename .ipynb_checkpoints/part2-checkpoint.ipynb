# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# colnames=['age', 'sex', 'chest pain type', 'resting blood pressure', 'serum cholestoral in mg/dl', 'fasting blood sugar > 120 mg/dl', 'resting electrocardiographic results', 'maximum heart rate achieved', 'exercise induced angina', 'oldpeak = ST depression induced by exercise relative to rest', 'the slope of the peak exercise ST segment', 'number of major vessels colored by flourosopy', 'thal', 'Absence/Presence']
colnames=['age', 'sex', 'chest pain', 'resting bp', 'cholestoral', 'fasting bs', 'resting ecg', 'max hr', 'exercise angina', 'oldpeak', 'slope of ST segment', '# of major vessels', 'thal', 'Disease Presence']

heart = pd.read_csv('data/heart.dat', delimiter=' ', index_col=False, names=colnames)
# heart.sample(10)

# %%
# Split the data into feature columns and target column
target_col = 'Disease Presence'
y = heart.loc[:, target_col]
X = heart.drop(['Disease Presence'], axis='columns')

# %%
# Do train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11)

# Train a logistic regression estimator
lr = LogisticRegression()
lr.fit(X_train, y_train)

# Calculate test-set accuracy
lr.score(X_test, y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8676470588235294

# %%
# Check class frequencies
y_test.value_counts(normalize=True)
# Out:
# 1    0.632353
# 2    0.367647
# Name: Disease Presence, dtype: float64

# %%
# Get the confusion matrix for our admissions model
y_pred = lr.predict(X_test)
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[39,  4],
#        [ 5, 20]])

# %%
#Measure the model's accuracy
accuracy = (39+20)/(39+4+5+20)
precision = (20/24)
recall = (20/25)

print(accuracy)
print(precision)
print(recall)
# Out:
# 0.8676470588235294
# 0.8333333333333334
# 0.8

# %%
fig, ax = plt.subplots(figsize=(13,13))
sns.heatmap(heart.corr(),
            vmin = -1,
            vmax = 1,
            cmap = sns.diverging_palette(220,10, n=21),
            annot=True,
            ax = ax
            );

# %%
heart.plot(kind='box', figsize=(20,20))

# %%
heart_excl_outliers = heart.loc[heart.loc[:,'cholestoral']<400,:]
heart_excl_outliers.shape
# Out:
# (266, 14)

# %%
#Distribution of data
axes = heart_excl_outliers.hist(figsize=(20, 15),bins=8)

# %%
# Scatter matrix of numerical columns
axes = sns.pairplot(heart_excl_outliers)
